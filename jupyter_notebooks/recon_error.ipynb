# %%
import matplotlib.pyplot as plt
import numpy as np
import glob, os
import scipy.io as sio
from scipy.signal import savgol_filter
import random
from scipy import stats

# %%
pca_m10 = np.zeros((8,14))
pca_m40 = np.zeros((8,14))
pca_m70 = np.zeros((8,14))
pca_m100 = np.zeros((8,14))

isomap_m10 = np.zeros((8,14))
isomap_m40 = np.zeros((8,14))
isomap_m70 = np.zeros((8,14))
isomap_m100 = np.zeros((8,14))

# %%
data_dir = '/home/cf620/git/prep_center_out/simulation/results/'

for i in range(1,9):

    pca_m10[i-1,:] = np.array(sio.loadmat(data_dir + '10002'+str(i)+'/1/var_pca.mat')['dist'])
    pca_m40[i-1,:] = np.array(sio.loadmat(data_dir + '10002'+str(i)+'/2/var_pca.mat')['dist'])
    pca_m70[i-1,:] = np.array(sio.loadmat(data_dir + '10002'+str(i)+'/3/var_pca.mat')['dist'])
    pca_m100[i-1,:] = np.array(sio.loadmat(data_dir + '10002'+str(i)+'/4/var_pca.mat')['dist'])

    isomap_m10[i-1,:] = np.array(sio.loadmat(data_dir + '10002'+str(i)+'/1/var_isomap.mat')['dist'])
    isomap_m40[i-1,:] = np.array(sio.loadmat(data_dir + '10002'+str(i)+'/2/var_isomap.mat')['dist'])
    isomap_m70[i-1,:] = np.array(sio.loadmat(data_dir + '10002'+str(i)+'/3/var_isomap.mat')['dist'])
    isomap_m100[i-1,:] = np.array(sio.loadmat(data_dir + '10002'+str(i)+'/4/var_isomap.mat')['dist'])

# %%
plt.figure()

fig, (ax0, ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=4, sharex=True,
                                    figsize=(14, 6))

#ax0.scatter(range(1,15), np.mean(pca_m10,axis=0), s=80, marker='^', c='navy')
ax0.plot(range(1,15), np.mean(pca_m10,axis=0), linewidth=2, c='navy', alpha=1.0)

#ax0.scatter(range(1,15), np.mean(isomap_m10,axis=0), s=80, marker='^', c='lightskyblue')
ax0.plot(range(1,15), np.mean(isomap_m10,axis=0), linewidth=2, c='lightskyblue', alpha=1.0)

#ax1.scatter(range(1,15), np.mean(pca_m40,axis=0), s=80, marker='^', c='navy')
ax1.plot(range(1,15), np.mean(pca_m40,axis=0), linewidth=2, c='navy', alpha=1.0)

#ax1.scatter(range(1,15), np.mean(isomap_m40,axis=0), s=80, marker='^', c='lightskyblue')
ax1.plot(range(1,15), np.mean(isomap_m40,axis=0), linewidth=2, c='lightskyblue', alpha=1.0)

#ax2.scatter(range(1,15), np.mean(pca_m70,axis=0), s=80, marker='^', c='navy')
ax2.plot(range(1,15), np.mean(pca_m70,axis=0), linewidth=2, c='navy', alpha=1.0)

#ax2.scatter(range(1,15), np.mean(isomap_m70,axis=0), s=80, marker='^', c='lightskyblue')
ax2.plot(range(1,15), np.mean(isomap_m70,axis=0), linewidth=2, c='lightskyblue', alpha=1.0)

#ax3.scatter(range(1,15), np.mean(pca_m100,axis=0), s=80, marker='^', c='navy')
ax3.plot(range(1,15), np.mean(pca_m100,axis=0), linewidth=2, c='navy', alpha=1.0)

#ax3.scatter(range(1,15), np.mean(isomap_m100,axis=0), s=80, marker='^', c='lightskyblue')
ax3.plot(range(1,15), np.mean(isomap_m100,axis=0), linewidth=2, c='lightskyblue', alpha=1.0)
